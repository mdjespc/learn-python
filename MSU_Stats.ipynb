# %% [markdown]
# <a href="https://colab.research.google.com/github/mdjespc/tutoring/blob/main/MSU_Stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import interactive

# %%
def plotDataFrame(file_name):
    # read the file_name into a pandas dataframe
    df = pd.read_csv(file_name)
    # plot the dataframe using arguments "title", "legend", "x", "y", "kind" and "color"
    x_axis = df.columns[0]
    y_axis = df.columns[1]
    fig = df.plot(x = 0, y = 1, title = file_name[:-4], legend = True, kind = 'bar', color = 'green', figsize = [12, 4])
    # Do not modify them.
    plt.xlabel(x_axis)      # Note: x-axis should be determined above
    plt.ylabel(y_axis)      # Note: y-axis should be determined above
    interactive(True)       # This allows multiple figures to be displayed simultaneously
    plt.show()

# %%
plotDataFrame("MSU College Enrollments.csv")
plotDataFrame("CS Faculty.csv")
